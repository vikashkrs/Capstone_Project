# %% [markdown]
# # Data wrangling<a id='2_Data_wrangling'></a>

# %% [markdown]
# ## 2.1 Contents<a id='2.1_Contents'></a>
# * [2 Data wrangling](#2_Data_wrangling)
#   * [2.1 Contents](#2.1_Contents)
#   * [2.2 Introduction](#2.2_Introduction)
#     * [2.2.1 Intoduction Of Data Science Problem](#2.2.1_Introduction_Of_Data_Science_Problem)
#     * [2.2.2 Data Collection Methodology](#2.2.2_Dataset_Methodology)
#     * [2.2.3 Dataset Information](#2.2.3_Dataset_Information)
#   * [2.3 Imports](#2.3_Imports)
#   * [2.4 Load The Survey Data](#2.4_Load_Survey_Data)
#   * [2.5 Explore The Data](#2.5_Explore_The_Data)
#   * [2.6 Explore The Supplementary Data](#2.6_Explore_The_Supplementary_Data)
#     * [2.6.1 Point to consider about supplementary questions](#2.6.1_Point_to_consider_about_Supplementary_Data)
#   * [2.7 Further data analysis in term of target variable](#2.7_Analysis_with_target_vaiable)

# %% [markdown]
# ## 2.2 Introduction<a id='2.2_Introduction'></a>

# %% [markdown]
# ### 2.2.1 Introduction Of Data Science Problem<a id='2.2.1_Introduction_Of_Data_Science_Problem'></a>

# %% [markdown]
# This is 2020 Survey data about DS(Data Science) and ML(Machine learning). It consists of data collected from different respondents across 171 different countries and territories. Survey consists of 35 questions, in which respondents have to select answers from drop down menu options. Tell a data story about a subset of the data science community represented in this survey, through a combination of both narrative text and data exploration. This survey can be used to predict salary range for different geographical locations for Data scientist based on multiple input paramters.

# %% [markdown]
# ### 2.2.2 Data Collection Methodology<a id='2.2.2_Dataset_Methodology'></a>

# %% [markdown]
# Data set is a DS & ML survey data conducted by Kaggle in 2020, where participant from 171 countries participated. The survey was live from 10/07/2020 to 10/30/2020 and responded were allowed to complete the survey at any time during that window.Responses to multiple choice questions (only a single choice can be selected) were recorded in
# individual columns. Responses to multiple selection questions (multiple choices can be selected)
# were split into multiple columns (with one column per answer choice).
# - Respondents with the most experience were asked the most questions. For example, students and unemployed persons were not asked questions about their employer. Likewise, respondents that do not write code were not asked questions about writing code.
# - For questions about cloud computing products, students and respondents that have never spent money in the cloud were given an alternate set of questions that asked them “what products they would like to become familiar with” instead of asking them “which products they use most often”. For questions with alternative phrasing, the questions were kept separate, and question types were labeled with either an “A” or a “B” (e.g. Q25A, Q25B, … , Q34A, Q34B).
# - Follow-up questions were only asked to respondents that answered the setup question affirmatively.
#    * Question 18 and Question 19 (which specific ML methods) were only asked to respondents that selected the relevant answer choices for Question 17 (which categories of algorithms).
#    * Question 27-A and Question 28-A (which specific AWS/Azure/GCP products) were only asked to respondents that selected the relevant answer choices for Question 26-A (which of the following companies).
#    * Question 30 (which specific product) was only asked to respondents that selected more than one choice for Question 29-A (which of the following products).
#    * Question 32 (which specific product) was only asked to respondents that selected more than one choice for Question 31-A (which of the following products).
#    * Question 34-A (which specific product) was only asked to respondents that answered affirmatively to Question 33-A (which of the following categories of products).

# %% [markdown]
# ### 2.2.2 Dataset Information<a id='2.2.3_Dataset_Information'></a>

# %% [markdown]
# - Q1: What is your age (# years)?
# - Q2: What is your gender
# - Q3: In which country do you currently reside?
# - Q4: What is the highest level of formal education that you have attained or plan to attain within the next 2 years?
# - Q5: Select the title most similar to your current role (or most recent title if retired):
# - Q6: For how many years have you been writing code and/or programming?
# - Q7: What programming languages do you use on a regular basis? (Select all that apply)
# - Q8: What programming language would you recommend an aspiring data scientist to learn first?
# - Q9: Which of the following integrated development environments (IDE's) do you use on a regular basis?(Select all that apply)
# - Q10: Which of the following hosted notebook products do you use on a regular basis? (Select all that apply)
# - Q11: What type of computing platform do you use most often for your data science projects?
# - Q12: Which types of specialized hardware do you use on a regular basis? (Select all that apply)
# - Q13: Approximately how many times have you used a TPU (tensor processing unit)?
# - Q14: What data visualization libraries or tools do you use on a regular basis? (Select all that apply)
# - Q15: For how many years have you used machine learning methods?
# - Q16: Which of the following machine learning frameworks do you use on a regular basis? (Select all that apply)
# - Q17: Which of the following ML algorithms do you use on a regular basis? (Select all that apply):
# - Q18: Which categories of computer vision methods do you use on a regular basis? (Select all that apply)
# - Q19: Which of the following natural language processing (NLP) methods do you use on a regular basis? (Select all that apply)
# - Q20: What is the size of the company where you are employed?
# - Q21: Approximately how many individuals are responsible for data science workloads at your place of business?
# - Q22: Does your current employer incorporate machine learning methods into their business?
# - Q23: Select any activities that make up an important part of your role at work: (Select all that apply)
# - Q24: What is your current yearly compensation ( approximate US Dollar )?
# - Q25: Approximately how much money have you (or your team) spent on machine learning and/or cloud computing services at home (or at work) in the past 5 years ( approximate US Dollar )?
# - Q26-A: Which of the following cloud computing platforms do you use on a regular basis? (Select all that apply)
# - Q27-A: Do you use any of the following cloud computing products on a regular basis? (Select all that apply)
# - Q28-A: Do you use any of the following machine learning products on a regular basis? (Select all that apply)
# - Q29-A: Which of the following big data products (relational databases, data warehouses, data lakes, or similar) do you use on a regular basis? (Select all that apply)
# - Q30: Which of the following big data products (relational database, data warehouse, data lake, or similar) do you use most often?
# - Q31-A: Which of the following business intelligence tools do you use on a regular basis? (Select all that apply)
# - Q32: Which of the following business intelligence tools do you use most often?
# - Q33-A: Do you use any automated machine learning tools (or partial AutoML tools) on a regular basis? (Select all that apply)
# - 34-A: Which of the following automated machine learning tools (or partial AutoML tools) do you use on a regular basis? (Select all that apply)
# - 35-A: Do you use any tools to help manage machine learning experiments? (Select all that apply)
# - 36: Where do you publicly share or deploy your data analysis or machine learning applications? (Select all that apply)
# - 37: On which platforms have you begun or completed data science courses? (Select all that apply)
# - 38: What is the primary tool that you use at work or school to analyze data? (Include text response)
# - 39: Who/what are your favorite media sources that report on data science topics? (Select all that apply)
#
# #### Supplementary Questions
# - Q26-B: Which of the following cloud computing platforms do you hope to become more familiar with in the next 2 years? (Select all that apply)
# - Q27-B: In the next 2 years, do you hope to become more familiar with any of these specific cloud computing products? (Select all that apply)
# - Q28-B: In the next 2 years, do you hope to become more familiar with any of these specific machine learning products? (Select all that apply)
# - Q29-B: Which of the following big data products (relational databases, data warehouses, data lakes, or similar) do you hope to become more familiar with in the next 2 years? (Select all that apply)
# - Q31-B: Which of the following business intelligence tools do you hope to become more familiar with in the next 2 years? (Select all that apply)
# - Q33-B: Which categories of automated machine learning tools (or partial AutoML tools) do you hope to become more familiar with in the next 2 years?  (Select all that apply)
# - 34-B: Which specific automated machine learning tools (or partial AutoML tools) do you hope to become more familiar with in the next 2 years?  (Select all that apply)
# - 35-B: In the next 2 years, do you hope to become more familiar with any of these tools for managing ML experiments? (Select all that apply)

# %% [markdown]
# ## 2.3 Imports<a id='2.3_Imports'></a>

# %%
# Importing all the required packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## 2.4 Load Survey Data<a id='2.4_Load_Survey_Data'></a>

# %%
# loading csv file into pandas dataframe and skipped the 1st row
df_survey = pd.read_csv('kaggle_survey_2020_responses.csv',low_memory=False,header=0,skiprows=[1])

# %%
# Displaying first five rows of data
df_survey.head()
# Out:
#    Time from Start to Finish (seconds)     Q1   Q2                        Q3  \
# 0                                 1838  35-39  Man                  Colombia
# 1                               289287  30-34  Man  United States of America
# 2                                  860  35-39  Man                 Argentina
# 3                                  507  30-34  Man  United States of America
# 4                                   78  30-34  Man                     Japan
#
#                   Q4                 Q5           Q6 Q7_Part_1 Q7_Part_2  \
# 0    Doctoral degree            Student   5-10 years    Python         R
# 1    Master’s degree      Data Engineer   5-10 years    Python         R
# 2  Bachelor’s degree  Software Engineer  10-20 years       NaN       NaN
# 3    Master’s degree     Data Scientist   5-10 years    Python       NaN
# 4    Master’s degree  Software Engineer    3-5 years    Python       NaN
#
# ...

# %% [markdown]
# From above data, we can that most of the columns have missing values, But this is because responses to multiple selection questions (multiple choices can be selected)were split into multiple columns (with one column per answer choice).

# %%
df_survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20036 entries, 0 to 20035
# Columns: 355 entries, Time from Start to Finish (seconds) to Q35_B_OTHER
# dtypes: int64(1), object(354)
# memory usage: 54.3+ MB

# %%
# Renaming column name from 'Time from Start to Finish (seconds)' to 'Time to Finish(seconds)' 
df_survey.rename(columns={'Time from Start to Finish (seconds)':'Time to Finish(seconds)'},inplace=True)

# %%
# displaying the shape of dataframe
df_survey.shape
# Out:
# (20036, 355)

# %% [markdown]
# `Data set have more than 20k rows and 355 columns`

# %% [markdown]
# ## 2.5 Explore The Data<a id='2.5_Explore_The_Data'></a>

# %%
#Displaying summary of all data point
df_survey.describe(include='all')
# Out:
#         Time to Finish(seconds)     Q1     Q2     Q3               Q4  \
# count              2.003600e+04  20036  20036  20036            19569
# unique                      NaN     11      5     55                7
# top                         NaN  25-29    Man  India  Master’s degree
# freq                        NaN   4011  15789   5851             7859
# mean               9.155865e+03    NaN    NaN    NaN              NaN
# std                6.136760e+04    NaN    NaN    NaN              NaN
# min                2.000000e+01    NaN    NaN    NaN              NaN
# 25%                3.980000e+02    NaN    NaN    NaN              NaN
# 50%                6.260000e+02    NaN    NaN    NaN              NaN
# 75%                1.030250e+03    NaN    NaN    NaN              NaN
# max                1.144493e+06    NaN    NaN    NaN              NaN
#
#              Q5         Q6 Q7_Part_1 Q7_Part_2 Q7_Part_3  ...  \
# count     19277      19120     15530      4277      7535  ...
# ...

# %%
# Displaying distribution of data for columns Q1,Q2,Q5,Q6

features = ['Q1', 'Q2', 'Q5', 'Q6'] # Creating list of columns Q1,Q2,Q5,Q6
sns.set_theme(style="darkgrid")
fig, ax = plt.subplots(2,2, figsize=(18,10))
axe = ax.ravel()
for i, c in enumerate(features):
    df_survey[c].value_counts().plot(kind='barh', ax=axe[i])
    plt.subplots_adjust(wspace=.4,hspace=.5)
    axe[i].tick_params(labelsize=13,rotation=0)
    axe[i].set_xlabel('Count',fontweight="bold")
    axe[0].set_title("Distribution of Age group",fontsize=15,fontweight="bold")
    axe[1].set_title("Gender of Participant",fontsize=15,fontweight="bold")
    axe[2].set_title("Title most similar to your current role",fontsize=15,fontweight="bold")
    axe[3].set_title("Number of experince in writing code",fontsize=15,fontweight="bold")

# %% [markdown]
# Analysis for each columns below:
#
# columns Q1: Highest number of the participant are in age group of 25-29, followed by 22-24. We can see here that around 3000 participant in age group of 18-21, which indicate that student who are in their 1st year of undergrad are also on kaggle platform.
#
# Column Q2: Most of the participant are Men and there are very few woman. It indicate that there is a huge gender gap in data science community.
#
# Column Q5: It shows there are large number of user on kaggle are students, who are learning and participating in kaggle learning and in competitions.
#
# Column Q6: Looks most of people who are in data science role have around 1 to 5 years of coding experience. Even there are group who have very high number of coding experince. Whereas there are people who have no prior experience in coding.

# %%
# display distribution of columns Q3
plt.figure(figsize=(18,12))
df_survey[['Q3']].value_counts().plot(kind='barh')
plt.ylabel("Country in which participant reside",fontsize=20).set_color('blue')
plt.xlabel("No of participant",fontsize=20).set_color('blue')
plt.title("No of participants from each country",fontweight="bold",fontsize=20)
# Out:
# Text(0.5, 1.0, 'No of participants from each country')

# %% [markdown]
# Most of the participant are from India followed by USA. Here countries or territory received less than 50 respondents. have been grouped named "other" for anonymity.

# %%
# Displaying distribution of column 'Q4'
df_survey['Q4'].value_counts().plot(kind='bar'); #Specify a horizontal barplot ('barh') as kind of plot (kind=)
plt.ylabel("No of participant",fontsize=15).set_color('blue')
plt.xlabel("Highest level of formal Education",fontsize=20).set_color('blue')
plt.title("highest level of formal education that you have attained or plan to attain within the next 2 years",fontweight="bold",fontsize=15)
# Out:
# Text(0.5, 1.0, 'highest level of formal education that you have attained or plan to attain within the next 2 years')

# %% [markdown]
# We can see from above analysis that, most of participant in data scinece community having Masters degree followed by Bachelor degree.

# %% [markdown]
# Transforming multiple columns of **Q7: What programming languages do you use on a regular basis? (Select all that apply)** into single column called **langauge**

# %%
# Transposing multiple columns for Q7 into single column
Q7_Programming_langauge = pd.melt(df_survey[['Q7_Part_1','Q7_Part_2','Q7_Part_3','Q7_Part_4','Q7_Part_5','Q7_Part_6','Q7_Part_7',
                             'Q7_Part_8','Q7_Part_9','Q7_Part_10','Q7_Part_11','Q7_Part_12','Q7_OTHER']],
                  var_name='col_name',value_name='language')

# %%
Q7_Programming_langauge.head()
# Out:
#     col_name language
# 0  Q7_Part_1   Python
# 1  Q7_Part_1   Python
# 2  Q7_Part_1      NaN
# 3  Q7_Part_1   Python
# 4  Q7_Part_1   Python

# %%
# Creating histogram to visualize the uses of different langage by data scientist
sns.countplot(x='language',data=Q7_Programming_langauge)
plt.xticks(rotation=90);
plt.xlabel("Programming Language")
plt.title("Programming language used on regular basis by data scientist",fontsize=12,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Programming language used on regular basis by data scientist')

# %% [markdown]
# From Q7 of survey, we can say python is the most popular langauge being used for data science community. Looks Julia is still far behind.

# %%
# Creating distribution of question Q8: "What programming language would you recommend an aspiring data scientist to learn first"

df_survey['Q8'].value_counts().plot(kind='bar');
plt.title("First language to learn as aspiring data scientist",fontsize=12,fontweight="bold")
plt.ylabel("count",fontsize=15,fontweight="bold")
plt.xlabel("Recommended language",fontsize=15,fontweight="bold")
# Out:
# Text(0.5, 0, 'Recommended language')

# %% [markdown]
# From Q8 of survey we can say that Python is the most recommended language in data science community. After that we have 'R', which is far behind in number

# %% [markdown]
# Transforming multiple columns of **Q9: Which of the following integrated development environments (IDE's) do you use on a regular basis?(Select all that apply)** into single column called **IDE**

# %%
# Transposing multiple columns for Q9 into single column
Q9_IDE = pd.melt(df_survey[['Q9_Part_1','Q9_Part_2','Q9_Part_3','Q9_Part_4','Q9_Part_5','Q9_Part_6','Q9_Part_7','Q9_Part_8','Q9_Part_9',
             'Q9_Part_10','Q9_Part_11','Q9_OTHER']],
                  var_name='col_name',value_name='IDE')

# %%
# Creating histogram to visualize the uses of different IDE by data scientist
sns.countplot(x='IDE',data=Q9_IDE)
plt.xticks(rotation=90);
plt.xlabel("IDE",fontweight="bold")
plt.title("IDE's being used on regular basis by data scientist",fontsize=12,fontweight="bold")
# Out:
# Text(0.5, 1.0, "IDE's being used on regular basis by data scientist")

# %% [markdown]
# From Q9 of survey we can Jupyter is extensively used IDE among data science community. Surprisinly RStudio is behind Pycharm and Visual studio code IDE's.

# %% [markdown]
# Transforming multiple columns of **Q10: Which of the following hosted notebook products do you use on a regular basis? (Select all that apply)** into single column called **Hosted_Notebooks**

# %%
# Transposing multiple columns for Q10 into single column
Q10_Notebooks = pd.melt(df_survey[['Q10_Part_1','Q10_Part_2','Q10_Part_3','Q10_Part_4','Q10_Part_5','Q10_Part_6','Q10_Part_7',
               'Q10_Part_8','Q10_Part_9','Q10_Part_10','Q10_Part_11','Q10_Part_12','Q10_Part_13','Q10_OTHER']],
                  var_name='col_name',value_name='Hosted_Notebooks')

# %%
# Creating histogram to visualize the uses of different hosted notebooks by data scientist
sns.countplot(x='Hosted_Notebooks',data=Q10_Notebooks)
plt.xticks(rotation=90);
plt.xlabel("Hosted_Notebooks",fontweight="bold")
plt.title("Hosted_Notebooks being used on regular basis by data scientist",fontsize=12,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Hosted_Notebooks being used on regular basis by data scientist')

# %% [markdown]
# Looks Colab and Kaggle are two most popular hosted notebooks, but point to be interest is still most of people not using hosted notebooks

# %%
# Creating histogram of Q11: "What type of computing platform do you use most often for your data science projects?"

df_survey['Q11'].value_counts().plot(kind='barh')
plt.ylabel("Type of computing platform",fontsize=15).set_color('blue')
plt.xlabel("Count",fontsize=15).set_color('blue')
plt.title("Distribution of computing platform used for data science projects",fontsize=12,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Distribution of computing platform used for data science projects')

# %% [markdown]
# Q11 of survey says that most of participant in data science community use local machine for day to day work

# %% [markdown]
# Transforming multiple columns of **Q12: Which types of specialized hardware do you use on a regular basis? (Select all that apply)** into single column called **Hardware**

# %%
Q12_Hardware = pd.melt(df_survey[['Q12_Part_1','Q12_Part_2','Q12_Part_3','Q12_OTHER']],
                  var_name='col_name',value_name='Hardware')

# %%
# Creating histogram to visualize the uses of different Hardware by data scientist
sns.countplot(x='Hardware',data=Q12_Hardware)
plt.xticks(rotation=90);
plt.xlabel("Specialized Hardware",fontweight="bold")
plt.title("Specialized Hardware being used on regular basis by data scientist",fontsize=12,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Specialized Hardware being used on regular basis by data scientist')

# %% [markdown]
# Q12 of survey say that most of people use GPU at the same time half of people do not use any specialized hardware

# %%
# Creating histogram of question Q13: "Approximately how many times have you used a TPU (tensor processing unit)?"

df_survey['Q13'].value_counts().plot(kind='barh')
plt.ylabel("Number of times TPU Used",fontsize=15).set_color('blue')
plt.xlabel("Count of TPU Use",fontsize=15).set_color('blue')
plt.title("TPU uses by participants",fontsize=12,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'TPU uses by participants')

# %% [markdown]
# Q13 support Q12 distribution, that few people use Google TPU

# %% [markdown]
# Transforming multiple columns of **Q14: What data visualization libraries or tools do you use on a regular basis? (Select all that apply)** into single column called **visualization libraries**

# %%
Q14_visualization = pd.melt(df_survey[['Q14_Part_1','Q14_Part_2','Q14_Part_3','Q14_Part_4','Q14_Part_5','Q14_Part_6','Q14_Part_7','Q14_Part_8',
               'Q14_Part_9','Q14_Part_10','Q14_Part_11','Q14_OTHER']],
                  var_name='col_name',value_name='visualization libraries')

# %%
# Creating histogram to visualize the uses of different visualization libraries by data scientist
sns.countplot(x='visualization libraries',data=Q14_visualization)
plt.xticks(rotation=90);
plt.xlabel("visualization libraries",fontweight="bold")
plt.title("visualization libraries being used on regular basis by data scientist",fontsize=12,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'visualization libraries being used on regular basis by data scientist')

# %% [markdown]
# It supports Q7 analysis, where participant selected "Python" as most used language, because of that Matplotlib and Seaborn is also being used extensibely as Vizualization tool. Matplotlib and Seaborn are part of python ecosystem

# %%
# Creating histogram of question Q15: "For how many years have you used machine learning methods?"

df_survey['Q15'].value_counts().plot(kind='barh')
plt.ylabel("Count",fontsize=15).set_color('blue')
plt.xlabel("Drop down option",fontsize=15).set_color('blue')
plt.title("Machine learning menthods used by Data Scientist",fontweight="bold")
plt.rc('figure', titlesize=14)

# %% [markdown]
# From above analysis, we can that most of people are using machine learning from last 5 years. There are few people who are using machine laerning from more than 5 years

# %% [markdown]
# Transforming multiple columns of **Q16: Which of the following machine learning frameworks do you use on a regular basis? (Select all that apply)** into single column called **ML_Frameworks**

# %%
Q16_ML_framework = pd.melt(df_survey[['Q16_Part_1','Q16_Part_2','Q16_Part_3','Q16_Part_4','Q16_Part_5','Q16_Part_6','Q16_Part_7','Q16_Part_8',
               'Q16_Part_9','Q16_Part_10','Q16_Part_11','Q16_Part_12','Q16_Part_13','Q16_Part_14','Q16_Part_15','Q16_OTHER']],
                  var_name='col_name',value_name='ML_Frameworks')

# %%
# Creating histogram to visualize the uses of different ML Framework by data scientist
sns.countplot(x='ML_Frameworks',data=Q16_ML_framework)
plt.xticks(rotation=90);
plt.xlabel("ML_Frameworks",fontweight="bold")
plt.title("ML_Frameworks being used on regular basis by data scientist",fontsize=12,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'ML_Frameworks being used on regular basis by data scientist')

# %% [markdown]
# As most of people use python for ML work, that why Scikit-Learn, TensorFlow, Keras and PyTorch ruling this chart.

# %% [markdown]
# Transforming multiple columns of **Q17: Which of the following ML algorithms do you use on a regular basis? (Select all that apply):** into single column called **ML algorithms**

# %%
Q17_ML_Algorithms = pd.melt(df_survey[['Q17_Part_1','Q17_Part_2','Q17_Part_3','Q17_Part_4','Q17_Part_5','Q17_Part_6','Q17_Part_7','Q17_Part_8',
               'Q17_Part_9','Q17_Part_10','Q17_Part_11','Q17_OTHER']],
                  var_name='col_name',value_name='ML_Algorithms')

# %%
# Creating histogram to visualize the uses of different ML Algorithms by data scientist
sns.countplot(x='ML_Algorithms',data=Q17_ML_Algorithms)
plt.xticks(rotation=90);
plt.xlabel("ML_Algorithms",fontweight="bold")
plt.title("ML_Algorithms being used on regular basis by data scientist",fontsize=12,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'ML_Algorithms being used on regular basis by data scientist')

# %% [markdown]
# `From above analysis it looks that most of the problem we can solve using classical Machine learning approach. Deep learning still far behind in common uses.`

# %% [markdown]
# Transforming multiple columns of **Q18: Which categories of computer vision methods do you use on a regular basis? (Select all that apply)** into single column called **Computer Vision**

# %%
Q18_computer_vision = pd.melt(df_survey[['Q18_Part_1','Q18_Part_2','Q18_Part_3','Q18_Part_4','Q18_Part_5','Q18_Part_6','Q18_OTHER']],
                  var_name='col_name',value_name='Computer_vision')

# %%
# Creating histogram to visualize the uses of different Computer vision by data scientist
sns.countplot(x='Computer_vision',data=Q18_computer_vision)
plt.xticks(rotation=90);
plt.xlabel("Computer_vision",fontweight="bold")
plt.title("Computer_vision being used on regular basis by data scientist",fontsize=12,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Computer_vision being used on regular basis by data scientist')

# %% [markdown]
# Most of people using General purpose Image classification methods

# %% [markdown]
# Transforming multiple columns of **Q19: Which of the following natural language processing (NLP) methods do you use on a regular basis? (Select all that apply)** into single column called **NLP**

# %%
Q19_NLP = pd.melt(df_survey[['Q19_Part_1','Q19_Part_2','Q19_Part_3','Q19_Part_4','Q19_Part_5','Q18_OTHER']],
                  var_name='col_name',value_name='NLP')

# %%
# Creating histogram to visualize the uses of different NLP by data scientist
sns.countplot(x='NLP',data=Q19_NLP)
plt.xticks(rotation=90);
plt.xlabel("NLP",fontweight="bold")
plt.title("NLP being used on regular basis by data scientist",fontsize=12,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'NLP being used on regular basis by data scientist')

# %% [markdown]
# Most of people using word vector technique for NLP work. Very few using BERT or GPT-3

# %%
# Creating histogram of question Q20: "What is the size of the company where you are employed?"

df_survey['Q20'].value_counts().plot(kind='bar')
plt.ylabel("Count",fontsize=15).set_color('blue')
plt.xlabel("Size of Company",fontsize=15).set_color('blue')
plt.title("Size of company where participant employed",fontsize=12,fontweight="bold")
plt.rc('figure', titlesize=14)

# %% [markdown]
# Looks there are many startup are coming in ML work

# %%
# Creating histogram of question Q21: "Approximately how many individuals are responsible for data science workloads at your place of
#business?"

df_survey['Q21'].value_counts().plot(kind='bar')
plt.ylabel("Count",fontsize=15).set_color('blue')
plt.xlabel("Data Science Team size",fontsize=15).set_color('blue')
plt.title("No of people in ML Team",fontsize=12,fontweight="bold")
plt.rc('figure', titlesize=14)

# %% [markdown]
# It suffice the distribution of Q20, we can see that most of organization have small ML team.

# %%
# Creating histogram of question Q22: "Does your current employer incorporate machine learning methods into their business?" 

df_survey['Q22'].value_counts().plot(kind='bar')
plt.ylabel("Count",fontsize=15).set_color('blue')
plt.xlabel("ML methods incoporation in business problem",fontsize=15).set_color('blue')
plt.title("ML methods incoporation in business problem",fontweight="bold")
plt.rc('figure', titlesize=14)

# %% [markdown]
# Transforming multiple columns of **Q23: Select any activities that make up an important part of your role at work: (Select all that apply)** into single column called **NLP**

# %%
Q23_Activity = pd.melt(df_survey[['Q23_Part_1','Q23_Part_2','Q23_Part_3','Q23_Part_4','Q23_Part_5','Q23_Part_6','Q23_Part_7','Q23_OTHER']],
                  var_name='col_name',value_name='Activity')

# %%
# Creating histogram to visualize the uses of different Activity by data scientist
sns.countplot(x='Activity',data=Q23_Activity)
plt.xticks(rotation=90);
plt.xlabel("Activity",fontweight="bold")
plt.title("Activity being used on regular basis by data scientist",fontsize=12,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Activity being used on regular basis by data scientist')

# %%
# Plotting histogram of Q24 below:

plt.figure(figsize=(10,8))
df_survey['Q24'].value_counts().plot(kind='bar')
plt.ylabel("Count",fontsize=15).set_color('blue')
plt.xlabel("Salary Range",fontsize=15).set_color('blue')
plt.title("Salary distribution of participants",fontsize=12,fontweight="bold")
plt.rc('figure', titlesize=14)

# %% [markdown]
# #### We can see that data point have dollar sign, we need to remove dollar sign from data points

# %%
# Stripping dollar sign from Q24

df_survey['Q24'] = df_survey['Q24'].str.replace('$', '')

# %%
# Ploting again after removing the dollar sign

plt.figure(figsize=(10,8))
df_survey['Q24'].value_counts().plot(kind='bar')
plt.ylabel("Count",fontsize=15).set_color('blue')
plt.xlabel("Salary Range without Dollar($) sign",fontsize=15).set_color('blue')
plt.title("Salary distribution of participants without dollar($) Sign",fontsize=12,fontweight="bold")
plt.rc('figure', titlesize=14)

# %%
#Creating histogram of question Q25:  Approximately how much money have you (or your team) spent on machine learning 
#and/or cloud computing services at home (or at work) in the past 5 years ( approximate $USD )

df_survey['Q25'].value_counts().plot(kind='bar')
plt.ylabel("Count",fontsize=15).set_color('blue')
plt.xlabel("Money spent on ML/Cloud Services",fontsize=15).set_color('blue')
plt.title("Money spent on ML/Cloud Services at Home or at Work",fontsize=12,fontweight="bold")
plt.rc('figure', titlesize=14)

# %% [markdown]
# Transforming multiple columns of **Q26-A: Which of the following cloud computing platforms do you use on a regular basis? (Select all that apply)** into single column called **Cloud_Computing_Platform**

# %%
Q26_A_Cloud_Computing = pd.melt(df_survey[['Q26_A_Part_1','Q26_A_Part_2','Q26_A_Part_3','Q26_A_Part_4','Q26_A_Part_5','Q26_A_Part_6','Q26_A_Part_7',
                'Q26_A_Part_8','Q26_A_Part_9','Q26_A_Part_10','Q26_A_Part_11','Q26_A_OTHER']],var_name='col_name',value_name='Cloud_Computing_Platform')

# %%
# Creating histogram to visualize the uses of different Cloud Computing platform by data scientist
sns.countplot(x='Cloud_Computing_Platform',data=Q26_A_Cloud_Computing)
plt.xticks(rotation=90);
plt.xlabel("Cloud Computing Platform",fontweight="bold")
plt.title("Cloud Computing Platform being used on regular basis by data scientist",fontsize=12,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Cloud Computing Platform being used on regular basis by data scientist')

# %% [markdown]
# From analysis of Q26-A, we can say that AWS is the most preferred cloud computing platform at the same there people who do not use any cloud computing platform for thier work

# %% [markdown]
# Transforming multiple columns of **Q27-A: Do you use any of the following cloud computing products on a regular basis? (Select all that apply)** into single column called **Cloud_Computing_Product**

# %%
Q27_A_Cloud_Computing_Product = pd.melt(df_survey[['Q27_A_Part_1','Q27_A_Part_2','Q27_A_Part_3','Q27_A_Part_4','Q27_A_Part_5','Q27_A_Part_6','Q27_A_Part_7',
                'Q27_A_Part_8','Q27_A_Part_9','Q27_A_Part_10','Q27_A_Part_11','Q27_A_OTHER']],var_name='col_name',value_name='Cloud_Computing_Product')

# %%
# Creating histogram to visualize the uses of different Cloud Computing product by data scientist
sns.countplot(x='Cloud_Computing_Product',data=Q27_A_Cloud_Computing_Product)
plt.xticks(rotation=90);
plt.xlabel("Cloud Computing Product",fontweight="bold")
plt.title("Cloud Computing Product being used on regular basis by data scientist",fontsize=12,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Cloud Computing Product being used on regular basis by data scientist')

# %% [markdown]
# It suffice question 26-A, where AWS is widespread used Computing platform

# %% [markdown]
# Transforming multiple columns of **Q28-A: Do you use any of the following machine learning products on a regular basis? (Select all that apply)** into single column called **ML_Product**

# %%
Q28_A_ML_Product = pd.melt(df_survey[['Q28_A_Part_1','Q28_A_Part_2','Q28_A_Part_3','Q28_A_Part_4','Q28_A_Part_5','Q28_A_Part_6','Q28_A_Part_7',
                'Q28_A_Part_8','Q28_A_Part_9','Q28_A_Part_10','Q28_A_OTHER']],var_name='col_name',value_name='ML_Product')

# %%
# Creating histogram to visualize the uses of different ML product by data scientist
sns.countplot(x='ML_Product',data=Q28_A_ML_Product)
plt.xticks(rotation=90);
plt.xlabel("ML Product",fontweight="bold")
plt.title("ML Product being used on regular basis by data scientist",fontsize=12,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'ML Product being used on regular basis by data scientist')

# %% [markdown]
# Looks still majarity of DS Communiyt do not use any ML Product

# %% [markdown]
# Transforming multiple columns of **Q29-A: Which of the following big data products (relational databases, data warehouses, data lakes, or similar) do you use on a regular basis? (Select all that apply)** into single column called **Big_data_Product**

# %%
Q29_A_Big_data_Product = pd.melt(df_survey[['Q29_A_Part_1','Q29_A_Part_2','Q29_A_Part_3','Q29_A_Part_4','Q29_A_Part_5','Q29_A_Part_6','Q29_A_Part_7',
                'Q29_A_Part_8','Q29_A_Part_9','Q29_A_Part_10','Q29_A_Part_11','Q29_A_Part_12','Q29_A_Part_13','Q29_A_Part_14',
                  'Q29_A_Part_15','Q29_A_Part_16','Q29_A_Part_17','Q29_A_OTHER']],var_name='col_name',value_name='Big_data_Product')

# %%
# Creating histogram to visualize the uses of different ML product by data scientist
sns.countplot(x='Big_data_Product',data=Q29_A_Big_data_Product)
plt.xticks(rotation=90);
plt.xlabel("Bigdata Product",fontweight="bold")
plt.title("Bigdata Product being used on regular basis by data scientist",fontsize=12,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Bigdata Product being used on regular basis by data scientist')

# %% [markdown]
# Most of Data Scientiest still using relation database than NoSQL databases

# %%
# Creating histogram of Q30: Which of the following big data products (relational database, data warehouse, data lake, or similar) do you use most often?
# This question was only asked to respondents that selected more than one choice for Question 29-A

df_survey['Q30'].value_counts().plot(kind='bar')
plt.ylabel("Count",fontsize=15).set_color('blue')
plt.xlabel("Specific Bigdata Product",fontsize=15).set_color('blue')
plt.title("Specific Big data Product",fontsize=12,fontweight="bold")
plt.rc('figure', titlesize=14)

# %% [markdown]
# Transforming multiple columns of **Q31-A: Which of the following business intelligence tools do you use on a regular basis? (Select all that apply)** into single column called **business intelligence tools**

# %%
Q31_A_business_intelligence_tools = pd.melt(df_survey[['Q31_A_Part_1','Q31_A_Part_2','Q31_A_Part_3','Q31_A_Part_4','Q31_A_Part_5','Q31_A_Part_6','Q31_A_Part_7',
                'Q31_A_Part_8','Q31_A_Part_9','Q31_A_Part_10','Q31_A_Part_11','Q31_A_Part_12','Q31_A_Part_13','Q31_A_Part_14',
                  'Q31_A_OTHER']],var_name='col_name',value_name='business intelligence tools')

# %%
# Creating histogram to visualize the uses of different ML product by data scientist
sns.countplot(x='business intelligence tools',data=Q31_A_business_intelligence_tools)
plt.xticks(rotation=90);
plt.xlabel("business intelligence tools",fontweight="bold")
plt.title("business intelligence tools being used on regular basis by data scientist",fontsize=12,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'business intelligence tools being used on regular basis by data scientist')

# %% [markdown]
# It gives clear picture that most of data scientist do not use any type of business intelligence tool

# %%
#Creating histogram of Q32: "Which of the following business intelligence tools do you use most often"
# Q32 was only asked to respondents that selected more than one choice for Question 31-A

df_survey['Q32'].value_counts().plot(kind='bar')
plt.ylabel("Count",fontsize=15).set_color('blue')
plt.xlabel("Specific Business Intelligence tool",fontsize=15).set_color('blue')
plt.title("Specific Business intelligence tools")
plt.rc('figure', titlesize=14)

# %% [markdown]
# Transforming multiple columns of **Q33-A: Do you use any automated machine learning tools (or partial AutoML tools) on a regular basis? (Select all that apply)** into single column called **Automated_ML_tools**

# %%
Q33_A_Automated_ML_tools = pd.melt(df_survey[['Q33_A_Part_1','Q33_A_Part_2','Q33_A_Part_3','Q33_A_Part_4','Q33_A_Part_5','Q33_A_Part_6','Q33_A_Part_7',
                  'Q33_A_OTHER']],var_name='col_name',value_name='Automated ML tools')

# %%
# Creating histogram to visualize the uses of different Automated ML tools by data scientist
sns.countplot(x='Automated ML tools',data=Q33_A_Automated_ML_tools)
plt.xticks(rotation=90);
plt.xlabel("Automated ML tools",fontweight="bold")
plt.title("Automated ML tools being used on regular basis by data scientist",fontsize=12,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Automated ML tools being used on regular basis by data scientist')

# %% [markdown]
# Most of people in Data Science community won't use automated ML tool for thier day to day work

# %% [markdown]
# Transforming multiple columns of **34-A: Which of the following automated machine learning tools (or partial AutoML tools) do you use on a regular basis? (Select all that apply)** into single column called **Specific_Automated_ML_tools**

# %%
Q34_A_Specific_Automated_ML_tools = pd.melt(df_survey[['Q34_A_Part_1','Q34_A_Part_2','Q34_A_Part_3','Q34_A_Part_4','Q34_A_Part_5','Q34_A_Part_6','Q34_A_Part_7',
                'Q34_A_Part_8','Q34_A_Part_9','Q34_A_Part_10','Q34_A_Part_11','Q34_A_OTHER']],var_name='col_name',value_name='Specific Automated ML tools')

# %%
# Creating histogram to visualize the uses of different Specific Automated ML tools by data scientist
# This Question was only asked to respondents that answered affirmatively to Question 33-A
sns.countplot(x='Specific Automated ML tools',data=Q34_A_Specific_Automated_ML_tools)
plt.xticks(rotation=90);
plt.xlabel("Specific Automated ML tools",fontweight="bold")
plt.title("Specific Automated ML tools being used on regular basis by data scientist",fontsize=12,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Specific Automated ML tools being used on regular basis by data scientist')

# %% [markdown]
# Transforming multiple columns of **35-A: Do you use any tools to help manage machine learning experiments? (Select all that apply)** into single column called **Help tool for ML Experiment**

# %%
Q35_A_Help_tool_for_ML_Experiment = pd.melt(df_survey[['Q35_A_Part_1','Q35_A_Part_2','Q35_A_Part_3','Q35_A_Part_4','Q35_A_Part_5','Q35_A_Part_6','Q35_A_Part_7',
                'Q35_A_Part_8','Q35_A_Part_9','Q35_A_Part_10','Q35_A_OTHER']],var_name='col_name',value_name='Help tool for ML Experiment')

# %%
# Creating histogram to visualize the uses of Help tools for ML experiment by data scientist

sns.countplot(x='Help tool for ML Experiment',data=Q35_A_Help_tool_for_ML_Experiment)
plt.xticks(rotation=90);
plt.xlabel("Help tool for ML Experiment",fontweight="bold")
plt.title("Help tools for ML experiment used by data scientist",fontsize=12,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Help tools for ML experiment used by data scientist')

# %% [markdown]
# Transforming multiple columns of **36: Where do you publicly share or deploy your data analysis or machine learning applications? (Select all that apply)** into single column called **Help tool for ML Experiment**

# %%
Q36_ML_Deployment_Space = pd.melt(df_survey[['Q36_Part_1','Q36_Part_2','Q36_Part_3','Q36_Part_4','Q36_Part_5','Q36_Part_6','Q36_Part_7','Q36_Part_8',
                'Q36_Part_9','Q36_OTHER']],var_name='col_name',value_name='ML Deployment Space')

# %%
# Creating histogram to visualize the uses of Help tools for ML experiment by data scientist

sns.countplot(x='ML Deployment Space',data=Q36_ML_Deployment_Space)
plt.xticks(rotation=90);
plt.xlabel("ML Deployment Space",fontweight="bold")
plt.title("Where DS share or deploy thier ML Applications",fontsize=12,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Where DS share or deploy thier ML Applications')

# %% [markdown]
# Github is the most prominent place where DS share or deploy their ML Application or ML Analysis

# %% [markdown]
# Transforming multiple columns of **37: On which platforms have you begun or completed data science courses? (Select all that apply)** into single column called **Platform to Learn DS**

# %%
Q37_Platform_to_Learn_DS = pd.melt(df_survey[['Q37_Part_1','Q37_Part_2','Q37_Part_3','Q37_Part_4','Q37_Part_5','Q37_Part_6','Q37_Part_7','Q37_Part_8',
                'Q37_Part_9','Q37_Part_10','Q37_Part_11','Q37_OTHER']],var_name='col_name',value_name='Platform to learn DS')

# %%
# Creating histogram to visualize the uses of Help tools for ML experiment by data scientist

sns.countplot(x='Platform to learn DS',data=Q37_Platform_to_Learn_DS)
plt.xticks(rotation=90);
plt.xlabel("Platform used to learn ML",fontweight="bold")
plt.title("Platform used to Learn Data Science",fontsize=12,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Platform used to Learn Data Science')

# %% [markdown]
# Coursera is the most prominent platform being used to learn Data Science

# %%
#Creating histogram of Q38:"What is the primary tool that you use at work or school to analyze data? (Include text response)"

df_survey['Q38'].value_counts().plot(kind='bar')
plt.ylabel("Count",fontsize=15).set_color('blue')
plt.xlabel("Data Analysis Tool",fontsize=15).set_color('blue')
plt.title("Primary tool used for data analysis")
plt.rc('figure', titlesize=14)

# %% [markdown]
# Looks most of people used local development environment for Data Analysis

# %% [markdown]
# Transforming multiple columns of **39:Who/what are your favorite media sources that report on data science topics? (Select all that apply)** into single column called **Favorite DS Topics**

# %%
Q39_DS_Topics = pd.melt(df_survey[['Q39_Part_1','Q39_Part_2','Q39_Part_3','Q39_Part_4','Q39_Part_5','Q39_Part_6','Q39_Part_7','Q39_Part_8',
                'Q39_Part_9','Q39_Part_10','Q39_Part_11','Q39_OTHER']],var_name='col_name',value_name='Favorite DS Topics')

# %%
# Creating histogram to visualize the favorite Media sources on data science topics

sns.countplot(x='Favorite DS Topics',data=Q39_DS_Topics)
plt.xticks(rotation=90);
plt.xlabel("Favorite Media Sources",fontweight="bold")
plt.title("favorite Media sources on data science topics",fontsize=12,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'favorite Media sources on data science topics')

# %% [markdown]
# Kaggle is a favorite media source among Data Science community.

# %% [markdown]
# ## 2.6 Explore The Supplementary Data<a id='2.6_Explore_The_Supplementary_Data'></a>

# %% [markdown]
# Transforming multiple columns of **Q26-B: Which of the following cloud computing platforms do you hope to become more familiar with in the next 2 years? (Select all that apply)** into single column called **Familiar in 2 years**

# %%
Q26_B = pd.melt(df_survey[['Q26_B_Part_1','Q26_B_Part_2','Q26_B_Part_3','Q26_B_Part_4','Q26_B_Part_5',
                                   'Q26_B_Part_6','Q26_B_Part_7','Q26_B_Part_8','Q26_B_Part_9','Q26_B_Part_10',
                                   'Q26_B_Part_11','Q26_B_OTHER']],var_name='col_name',value_name='Familiar in 2 years')

# %%
# Creating histogram to visualize Q26-B

sns.countplot(x='Familiar in 2 years',data=Q26_B)
plt.xticks(rotation=90);
plt.xlabel("Familiarity with Cloud computing",fontweight="bold")
plt.title("Getting familiar with Cloud Computing in next 2 Years",fontsize=12,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Getting familiar with Cloud Computing in next 2 Years')

# %% [markdown]
# Looks most of people are planning to get familiar with AWS and GCP in next 2 years

# %% [markdown]
# Transforming multiple columns of **Q27-B: In the next 2 years, do you hope to become more familiar with any of these specific cloud computing products? (Select all that apply)** into single column called **Familiar in 2 years**

# %%
Q27_B = pd.melt(df_survey[['Q27_B_Part_1','Q27_B_Part_2','Q27_B_Part_3','Q27_B_Part_4','Q27_B_Part_5','Q27_B_Part_6','Q27_B_Part_7',
                'Q27_B_Part_8','Q27_B_Part_9','Q27_B_Part_10','Q27_B_Part_11','Q27_B_OTHER']],var_name='col_name',value_name='Familiar in 2 years')

# %%
# Creating histogram to visualize Q27-B

sns.countplot(x='Familiar in 2 years',data=Q27_B)
plt.xticks(rotation=90);
plt.xlabel("Familiarity with Cloud computing Product",fontweight="bold")
plt.title("Getting familiar with Cloud Computing Product in next 2 Years",fontsize=12,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Getting familiar with Cloud Computing Product in next 2 Years')

# %% [markdown]
# Most of people planning to get familiar with GCP Engine.

# %% [markdown]
# Transforming multiple columns of **Q28-B: In the next 2 years, do you hope to become more familiar with any of these specific machine learning products? (Select all that apply)** into single column called **Familiar in 2 years**

# %%
Q28_B = pd.melt(df_survey[['Q28_B_Part_1','Q28_B_Part_2','Q28_B_Part_3','Q28_B_Part_4','Q28_B_Part_5','Q28_B_Part_6','Q28_B_Part_7',
                'Q28_B_Part_8','Q28_B_Part_9','Q28_B_Part_10','Q28_B_OTHER']],var_name='col_name',value_name='Familiar in 2 years')

# %%
# Creating histogram to visualize Q28-B

sns.countplot(x='Familiar in 2 years',data=Q28_B)
plt.xticks(rotation=90);
plt.xlabel("Familiarity with ML Product",fontweight="bold")
plt.title("Getting familiar with ML Product in next 2 Years",fontsize=12,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Getting familiar with ML Product in next 2 Years')

# %% [markdown]
# Most of people are planning to get familiar with Google ML Platform

# %% [markdown]
# Transforming multiple columns of **Q29-B: Which of the following big data products (relational databases, data warehouses, data lakes, or similar) do you hope to become more familiar with in the next 2 years? (Select all that apply)** into single column called **Familiar in 2 years**

# %%
Q29_B = pd.melt(df_survey[['Q29_B_Part_1','Q29_B_Part_2','Q29_B_Part_3','Q29_B_Part_4','Q29_B_Part_5','Q29_B_Part_6','Q29_B_Part_7',
                'Q29_B_Part_8','Q29_B_Part_9','Q29_B_Part_10','Q29_B_Part_11','Q29_B_Part_12','Q29_B_Part_13','Q29_B_Part_14',
                  'Q29_B_Part_15','Q29_B_Part_16','Q29_B_Part_17','Q29_A_OTHER']],var_name='col_name',value_name='Familiar in 2 years')

# %%
# Creating histogram to visualize Q29-B

sns.countplot(x='Familiar in 2 years',data=Q29_B)
plt.xticks(rotation=90);
plt.xlabel("Familiarity with Bigdata Product",fontweight="bold")
plt.title("Getting familiar with Bigdata Product in next 2 Years",fontsize=12,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Getting familiar with Bigdata Product in next 2 Years')

# %% [markdown]
# Most of people are looking to get familiar with MySQL and MongoDB in next 2 years

# %% [markdown]
# Transforming multiple columns of **Q31-B: Which of the following business intelligence tools do you hope to become more familiar with in the next 2 years? (Select all that apply)** into single column called **Familiar in 2 years**

# %%
Q31_B = pd.melt(df_survey[['Q31_B_Part_1','Q31_B_Part_2','Q31_B_Part_3','Q31_B_Part_4','Q31_B_Part_5','Q31_B_Part_6','Q31_B_Part_7',
                'Q31_B_Part_8','Q31_B_Part_9','Q31_B_Part_10','Q31_B_Part_11','Q31_B_Part_12','Q31_B_Part_13','Q31_B_Part_14',
                  'Q31_B_OTHER']],var_name='col_name',value_name='Familiar in 2 years')

# %%
# Creating histogram to visualize Q31-B

sns.countplot(x='Familiar in 2 years',data=Q31_B)
plt.xticks(rotation=90);
plt.xlabel("Familiarity with business intelligence tools",fontweight="bold")
plt.title("Getting familiar with business intelligence tools in next 2 Years",fontsize=12,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Getting familiar with business intelligence tools in next 2 Years')

# %% [markdown]
# looks Tableau is most in demand in future as most people are opting for Tableau to learn in next 2 years

# %% [markdown]
# Transforming multiple columns of **Q33-B: Which categories of automated machine learning tools (or partial AutoML tools) do you hope to become more familiar with in the next 2 years? (Select all that apply)** into single column called **Familiar in 2 years**

# %%
Q33_B = pd.melt(df_survey[['Q33_B_Part_1','Q33_B_Part_2','Q33_B_Part_3','Q33_B_Part_4','Q33_B_Part_5','Q33_B_Part_6','Q33_B_Part_7',
                  'Q33_B_OTHER']],var_name='col_name',value_name='Familiar in 2 years')

# %%
# Creating histogram to visualize Q33-B

sns.countplot(x='Familiar in 2 years',data=Q33_B)
plt.xticks(rotation=90);
plt.xlabel("Familiarity with automated machine learning tools",fontweight="bold")
plt.title("Getting familiar with automated machine learning tools in next 2 Years",fontsize=12,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Getting familiar with automated machine learning tools in next 2 Years')

# %% [markdown]
# People are more focused on automating ML Pipeline workflow

# %% [markdown]
# Transforming multiple columns of **34-B: Which specific automated machine learning tools (or partial AutoML tools) do you hope to become more familiar with in the next 2 years? (Select all that apply)** into single column called **Familiar in 2 years**

# %%
Q34_B = pd.melt(df_survey[['Q34_B_Part_1','Q34_B_Part_2','Q34_B_Part_3','Q34_B_Part_4','Q34_B_Part_5','Q34_B_Part_6','Q34_B_Part_7',
                'Q34_B_Part_8','Q34_B_Part_9','Q34_B_Part_10','Q34_B_Part_11','Q34_B_OTHER']],var_name='col_name',value_name='Familiar in 2 years')

# %%
# Creating histogram to visualize Q34-B

sns.countplot(x='Familiar in 2 years',data=Q34_B)
plt.xticks(rotation=90);
plt.xlabel("Familiarity with automated machine learning tools",fontweight="bold")
plt.title("Getting familiar with automated machine learning tools in next 2 Years",fontsize=12,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Getting familiar with automated machine learning tools in next 2 Years')

# %% [markdown]
# Transforming multiple columns of **35-B: In the next 2 years, do you hope to become more familiar with any of these tools for managing ML experiments? (Select all that apply)? (Select all that apply)** into single column called **Familiar in 2 years**

# %%
Q35_B = pd.melt(df_survey[['Q35_B_Part_1','Q35_B_Part_2','Q35_B_Part_3','Q35_B_Part_4','Q35_B_Part_5','Q35_B_Part_6','Q35_B_Part_7',
                'Q35_B_Part_8','Q35_B_Part_9','Q35_B_Part_10','Q35_B_OTHER']],var_name='col_name',value_name='Familiar in 2 years')

# %%
# Creating histogram to visualize Q35-B

sns.countplot(x='Familiar in 2 years',data=Q35_B)
plt.xticks(rotation=90);
plt.xlabel("Familiarity with tools managing ML experiments",fontweight="bold")
plt.title("Getting familiar with tools managing ML experiments in next 2 Years",fontsize=12,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Getting familiar with tools managing ML experiments in next 2 Years')

# %% [markdown]
# TensorBoard is in High demand among Aspiring Data Scientist

# %% [markdown]
# ## 2.6.1 Point to consider about supplementary questions<a id='2.6.1_Point_to_consider_about_Supplementary_Data'></a>

# %% [markdown]
# Here point to be noted that, all the supplemenatry questions were asked to Students, Unemployed or some of cloud related supplementary question asked to students and respondent who never spent money in cloud. Here our target varaible is "current yearly compensation", In that case we can Ignore the supplementary questions while creating our model.

# %% [markdown]
# ## 2.7 Further data analysis in term of target variable<a id='2.7_Analysis_with_target_vaiable'></a>

# %%
pd.crosstab(df_survey['Q24'],df_survey['Q5'])
# Out:
# Q5               Business Analyst  DBA/Database Engineer  Data Analyst  \
# Q24
# 0-999                         114                     14           301
# 1,000-1,999                    32                      9            87
# 10,000-14,999                  50                      8            85
# 100,000-124,999                42                      9            51
# 125,000-149,999                 9                      4            16
# 15,000-19,999                  28                      6            61
# 150,000-199,999                 9                      1             8
# 2,000-2,999                    24                      3            39
# 20,000-24,999                  32                      6            43
# 200,000-249,999                 6                      0             5
# 25,000-29,999                  21                      4            36
# 250,000-299,999                 0                      0             0
# ...

# %%
df_survey.groupby(['Q20','Q24']).sum().head(10)
# Out:
#                                 Time to Finish(seconds)
# Q20            Q24
# 0-49 employees 0-999                           15498984
#                1,000-1,999                      2571368
#                10,000-14,999                    1889640
#                100,000-124,999                  3110075
#                125,000-149,999                  1503835
#                15,000-19,999                    1516346
#                150,000-199,999                   179586
#                2,000-2,999                      1079115
#                20,000-24,999                     689792
#                200,000-249,999                   410612
